# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\DELL\Downloads\loan_approval_data.csv")

# %%
df
# Out:
#      Applicant_ID  Applicant_Income  Coapplicant_Income Employment_Status  \
# 0             1.0           17795.0              1387.0          Salaried
# 1             2.0            2860.0              2679.0          Salaried
# 2             3.0            7390.0              2106.0          Salaried
# 3             4.0           13964.0              8173.0          Salaried
# 4             5.0           13284.0              4223.0     Self-employed
# ..            ...               ...                 ...               ...
# 995         996.0               NaN              9092.0          Salaried
# 996         997.0            3279.0              6356.0     Self-employed
# 997         998.0           15192.0              8433.0          Contract
# 998         999.0            9083.0              7380.0        Unemployed
# 999        1000.0           13093.0              2385.0          Salaried
#
#       Age Marital_Status  Dependents  Credit_Score  Existing_Loans  DTI_Ratio  \
# ...

# %%
df=df.drop_duplicates()

# %%
df
# Out:
#      Applicant_ID  Applicant_Income  Coapplicant_Income Employment_Status  \
# 0             1.0           17795.0              1387.0          Salaried
# 1             2.0            2860.0              2679.0          Salaried
# 2             3.0            7390.0              2106.0          Salaried
# 3             4.0           13964.0              8173.0          Salaried
# 4             5.0           13284.0              4223.0     Self-employed
# ..            ...               ...                 ...               ...
# 995         996.0               NaN              9092.0          Salaried
# 996         997.0            3279.0              6356.0     Self-employed
# 997         998.0           15192.0              8433.0          Contract
# 998         999.0            9083.0              7380.0        Unemployed
# 999        1000.0           13093.0              2385.0          Salaried
#
#       Age Marital_Status  Dependents  Credit_Score  Existing_Loans  DTI_Ratio  \
# ...

# %%
x=df.drop("Loan_Approved",axis=1)
y=df["Loan_Approved"]

# %%
from sklearn.preprocessing import LabelEncoder

# 1. Initialize the encoder
le = LabelEncoder()

# 2. Fit and transform the column in-place
x["Employment_Status"] = le.fit_transform(x["Employment_Status"])
x["Marital_Status"] = le.fit_transform(x["Marital_Status"])
x["Employer_Category"] = le.fit_transform(x["Employer_Category"])
x["Loan_Purpose"] = le.fit_transform(x["Loan_Purpose"])
x["Property_Area"] = le.fit_transform(x["Property_Area"])
x["Gender"] = le.fit_transform(x["Gender"])

# %%
x
# Out:
#      Applicant_ID  Applicant_Income  Coapplicant_Income  Employment_Status  \
# 0             1.0           17795.0              1387.0                  1
# 1             2.0            2860.0              2679.0                  1
# 2             3.0            7390.0              2106.0                  1
# 3             4.0           13964.0              8173.0                  1
# 4             5.0           13284.0              4223.0                  2
# ..            ...               ...                 ...                ...
# 995         996.0               NaN              9092.0                  1
# 996         997.0            3279.0              6356.0                  2
# 997         998.0           15192.0              8433.0                  0
# 998         999.0            9083.0              7380.0                  3
# 999        1000.0           13093.0              2385.0                  1
#
# ...

# %%
df.isnull().sum()
# Out:
# Applicant_ID          50
# Applicant_Income      50
# Coapplicant_Income    50
# Employment_Status     50
# Age                   50
# Marital_Status        50
# Dependents            50
# Credit_Score          50
# Existing_Loans        50
# DTI_Ratio             50
# Savings               50
# Collateral_Value      50
# Loan_Amount           50
# Loan_Term             50
# Loan_Purpose          50
# Property_Area         50
# Education_Level       50
# Gender                50
# Employer_Category     50
# Loan_Approved         50
# dtype: int64

# %%
df=df.dropna(how="all")

# %%
df
# Out:
#      Applicant_ID  Applicant_Income  Coapplicant_Income Employment_Status  \
# 0             1.0           17795.0              1387.0          Salaried
# 1             2.0            2860.0              2679.0          Salaried
# 2             3.0            7390.0              2106.0          Salaried
# 3             4.0           13964.0              8173.0          Salaried
# 4             5.0           13284.0              4223.0     Self-employed
# ..            ...               ...                 ...               ...
# 995         996.0               NaN              9092.0          Salaried
# 996         997.0            3279.0              6356.0     Self-employed
# 997         998.0           15192.0              8433.0          Contract
# 998         999.0            9083.0              7380.0        Unemployed
# 999        1000.0           13093.0              2385.0          Salaried
#
#       Age Marital_Status  Dependents  Credit_Score  Existing_Loans  DTI_Ratio  \
# ...

# %%
num_cols = [
    'Applicant_Income', 'Coapplicant_Income', 'Age', 'Credit_Score', 
    'Existing_Loans', 'DTI_Ratio', 'Savings', 'Collateral_Value', 
    'Loan_Amount', 'Loan_Term'
]

# Fill missing values with the median of each column
for col in num_cols:
    df[col] = df[col].fillna(df[col].median())

# %%
cat_cols = ['Employment_Status', 'Marital_Status', 'Loan_Purpose', 
            'Property_Area', 'Education_Level', 'Gender', 'Employer_Category']

for col in cat_cols:
    df[col] = df[col].fillna(df[col].mode()[0])

# %%
x.isnull().sum()
# Out:
# Applicant_ID          50
# Applicant_Income      50
# Coapplicant_Income    50
# Employment_Status      0
# Age                   50
# Marital_Status         0
# Dependents            50
# Credit_Score          50
# Existing_Loans        50
# DTI_Ratio             50
# Savings               50
# Collateral_Value      50
# Loan_Amount           50
# Loan_Term             50
# Loan_Purpose           0
# Property_Area          0
# Education_Level       50
# Gender                 0
# Employer_Category      0
# dtype: int64

# %%
x = df.drop(columns=['Loan_Approved'],axis=1)

# %%
y=df["Loan_Approved"]

# %%
x.isnull().sum()
# Out:
# Applicant_ID          50
# Applicant_Income       0
# Coapplicant_Income     0
# Employment_Status      0
# Age                    0
# Marital_Status         0
# Dependents            50
# Credit_Score           0
# Existing_Loans         0
# DTI_Ratio              0
# Savings                0
# Collateral_Value       0
# Loan_Amount            0
# Loan_Term              0
# Loan_Purpose           0
# Property_Area          0
# Education_Level        0
# Gender                 0
# Employer_Category      0
# dtype: int64

# %%
x = x.drop(columns=['Applicant_ID'])
x['Dependents'] = x['Dependents'].fillna(x['Dependents'].mode()[0])

# %%
x.isnull().sum()
# Out:
# Applicant_Income      0
# Coapplicant_Income    0
# Employment_Status     0
# Age                   0
# Marital_Status        0
# Dependents            0
# Credit_Score          0
# Existing_Loans        0
# DTI_Ratio             0
# Savings               0
# Collateral_Value      0
# Loan_Amount           0
# Loan_Term             0
# Loan_Purpose          0
# Property_Area         0
# Education_Level       0
# Gender                0
# Employer_Category     0
# dtype: int64

# %%
from sklearn.linear_model import LogisticRegression

# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\DELL\Downloads\loan_approval_data.csv")

# %%
x=df.drop("Loan_Approved",axis=1)
y=df["Loan_Approved"]

# %%
from sklearn.preprocessing import LabelEncoder

# 1. Initialize the encoder
le = LabelEncoder()

# 2. Fit and transform the column in-place
x["Employment_Status"] = le.fit_transform(x["Employment_Status"])
x["Marital_Status"] = le.fit_transform(x["Marital_Status"])
x["Employer_Category"] = le.fit_transform(x["Employer_Category"])
x["Loan_Purpose"] = le.fit_transform(x["Loan_Purpose"])
x["Property_Area"] = le.fit_transform(x["Property_Area"])
x["Gender"] = le.fit_transform(x["Gender"])

# %%
num_cols = [
    'Applicant_Income', 'Coapplicant_Income', 'Age', 'Credit_Score', 
    'Existing_Loans', 'DTI_Ratio', 'Savings', 'Collateral_Value', 
    'Loan_Amount', 'Loan_Term'
]

# Fill missing values with the median of each column
for col in num_cols:
    df[col] = df[col].fillna(df[col].median())

# %%
cat_cols = ['Employment_Status', 'Marital_Status', 'Loan_Purpose', 
            'Property_Area', 'Education_Level', 'Gender', 'Employer_Category']

for col in cat_cols:
    df[col] = df[col].fillna(df[col].mode()[0])

# %%
x.isnull().sum()
# Out:
# Applicant_ID          50
# Applicant_Income      50
# Coapplicant_Income    50
# Employment_Status      0
# Age                   50
# Marital_Status         0
# Dependents            50
# Credit_Score          50
# Existing_Loans        50
# DTI_Ratio             50
# Savings               50
# Collateral_Value      50
# Loan_Amount           50
# Loan_Term             50
# Loan_Purpose           0
# Property_Area          0
# Education_Level       50
# Gender                 0
# Employer_Category      0
# dtype: int64

# %%
x = x.drop(columns=['Applicant_ID'])
x['Dependents'] = x['Dependents'].fillna(x['Dependents'].mode()[0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 x = x.drop(columns=['Applicant_ID'])
#       2 x['Dependents'] = x['Dependents'].fillna(x['Dependents'].mode()[0])
#
# NameError: name 'x' is not defined

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(
    
    x, y, test_size=0.2, random_state=42)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 4
#       1 from sklearn.model_selection import train_test_split
#       2 x_train, x_test, y_train, y_test = train_test_split(
#       3
# ----> 4     x, y, test_size=0.2, random_state=42)
#
# NameError: name 'x' is not defined

# %%
from sklearn.preprocessing import StandardScaler
s=StandardScaler()
x_train_scaled=x_train.fit_transform()
x_test_scaled=x_test.transform()
